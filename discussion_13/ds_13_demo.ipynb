# %% [markdown]
# <h1>SI 305 Discussion 10</h1>
#
# Demo of how to construct a two sample t-test using stats model

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

# %%
df = pd.read_csv("https://docs.google.com/spreadsheets/d/1eaSNxbuMfR9_OzsqDAUJSGhm0OxohaXosFZs8vlPpd0/gviz/tq?tqx=out:csv")

# %% [markdown]
# <h2>t-test</h2>

# %%
df = df[df['DO_FIELD'] < 100]
df['Location description'] = df['Location description'].apply(lambda s: np.where('Site 1' in s, 'Site 1', 
                                                                                 np.where('Site 2' in s, 'Site 2', 'Site 3')))

# %%
sns.displot(data = df, x = 'DO_FIELD', col = 'Location description')

# %%
site_1 = df[df['Location description'] == 'Site 1']['DO_FIELD']
site_2 = df[df['Location description'] == 'Site 2']['DO_FIELD']

sm.stats.ttest_ind(site_1, site_2)
# Out:
# (-0.37368955791325514, 0.7087153042740553, 990.0)
